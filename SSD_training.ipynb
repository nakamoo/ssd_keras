# %%
import cv2
import keras
from keras.applications.imagenet_utils import preprocess_input
from keras.backend.tensorflow_backend import set_session
from keras.models import Model
from keras.preprocessing import image
import matplotlib.pyplot as plt
import numpy as np
import pickle
from random import shuffle
from scipy.misc import imread
from scipy.misc import imresize
import tensorflow as tf

from ssd import SSD300
from ssd_training import MultiboxLoss
from ssd_utils import BBoxUtility

# %matplotlib inline
plt.rcParams['figure.figsize'] = (8, 8)
plt.rcParams['image.interpolation'] = 'nearest'

np.set_printoptions(suppress=True)

# config = tf.ConfigProto()
# config.gpu_options.per_process_gpu_memory_fraction = 0.9
# set_session(tf.Session(config=config))
# Out:
# Using TensorFlow backend.

# %%
# some constants
NUM_CLASSES = 3
input_shape = (300, 300, 3)

# %%
priors = pickle.load(open('prior_boxes_ssd300.pkl', 'rb'))
bbox_util = BBoxUtility(NUM_CLASSES, priors)

# %%
from PASCAL_VOC.get_data_from_XML import XML_preprocessor
parsed_data = XML_preprocessor("VOCdevkit/VOC2007/Annotations/")
gt = parsed_data.data
# gt = pickle.load(open('gt_pascal.pkl', 'rb'))
keys = sorted(gt.keys())
num_train = int(round(0.95 * len(keys)))
train_keys = keys[:num_train]
val_keys = keys[num_train:]
num_val = len(val_keys)
# Out:
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: sofa
# unknown label: sofa
# unknown label: crashedbottle
# unknown label: crashedbottle
# unknown label: crashedbottle
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: diningtable
# unknown label: diningtable
# unknown label: person
# unknown label: diningtable
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: diningtable
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: sofa
# unknown label: chair
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: diningtable
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: diningtable
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: chair
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: diningtable
# unknown label: chair
# unknown label: diningtable
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: chair
# unknown label: chair
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: pottedplant
# unknown label: chair
# unknown label: crashedbottle
# unknown label: sofa
# unknown label: chair
# unknown label: tvmonitor
# unknown label: chair
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: crashedbottle
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: diningtable
# unknown label: person
# unknown label: tvmonitor
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: diningtable
# unknown label: person
# unknown label: person
# unknown label: chair
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: dog
# unknown label: pottedplant
# unknown label: person
# unknown label: person
# unknown label: chair
# unknown label: chair
# unknown label: person
# unknown label: person
# unknown label: crashedbottle
# unknown label: crashedbottle
# unknown label: crashedbottle
# unknown label: diningtable
# unknown label: person
# unknown label: person
# unknown label: pottedplant
# unknown label: crashedbottle
# unknown label: person
# unknown label: tvmonitor
# unknown label: tvmonitor
# unknown label: chair
# unknown label: tvmonitor
# unknown label: diningtable
# unknown label: diningtable
# unknown label: diningtable
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: crashedbottle
# unknown label: crashedbottle
# unknown label: person
# unknown label: crashedbottle
# unknown label: diningtable
# unknown label: chair
# unknown label: chair
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: sofa
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: diningtable
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: sofa
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: diningtable
# unknown label: crashedbottle
# unknown label: person
# unknown label: crashedbottle
# unknown label: crashedbottle
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: bicycle
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: chair
# unknown label: chair
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: sofa
# unknown label: pottedplant
# unknown label: tvmonitor
# unknown label: chair
# unknown label: person
# unknown label: sheep
# unknown label: sheep
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: crashedbottle
# unknown label: crashedbottle
# unknown label: person
# unknown label: person
# unknown label: diningtable
# unknown label: diningtable
# unknown label: chair
# unknown label: person
# unknown label: person
# unknown label: pottedplant
# unknown label: tvmonitor
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: diningtable
# unknown label: person
# unknown label: chair
# unknown label: crashedbottle
# unknown label: crashedbottle
# unknown label: crashedbottle
# unknown label: diningtable
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: bus
# unknown label: car
# unknown label: car
# unknown label: car
# unknown label: car
# unknown label: person
# unknown label: crashedbottle
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: sofa
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: diningtable
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: crashedbottle
# unknown label: diningtable
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: crashedbottle
# unknown label: crashedbottle
# unknown label: diningtable
# unknown label: pottedplant
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: diningtable
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: tvmonitor
# unknown label: person
# unknown label: person
# unknown label: diningtable
# unknown label: crashedbottle
# unknown label: tvmonitor
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: crashedbottle
# unknown label: person
# unknown label: crashedbottle
# unknown label: crashedbottle
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: diningtable
# unknown label: diningtable
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: person
# unknown label: chair
# unknown label: chair
# unknown label: person
# unknown label: diningtable
# unknown label: tvmonitor
# unknown label: chair
# unknown label: person
# unknown label: diningtable
# unknown label: tvmonitor
# unknown label: chair
# unknown label: cat
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: diningtable
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: diningtable
# unknown label: chair
# unknown label: chair
# unknown label: diningtable
# unknown label: chair
# unknown label: pottedplant
# unknown label: person
# unknown label: person
# unknown label: diningtable
# unknown label: tvmonitor
# unknown label: bicycle
# unknown label: chair
# unknown label: chair
# unknown label: car
# unknown label: car
# unknown label: sofa
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: pottedplant
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: diningtable
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: crashedbottle
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: cat
# unknown label: tvmonitor
# unknown label: person
# unknown label: person
# unknown label: sofa
# unknown label: person
# unknown label: cat
# unknown label: cat
# unknown label: tvmonitor
# unknown label: diningtable
# unknown label: person
# unknown label: person
# unknown label: sofa
# unknown label: diningtable
# unknown label: diningtable
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: person
# unknown label: person
# unknown label: chair
# unknown label: chair
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: diningtable
# unknown label: person
# unknown label: crashedbottle
# unknown label: crashedbottle
# unknown label: person
# unknown label: diningtable
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: chair
# unknown label: chair
# unknown label: diningtable
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: crashedbottle
# unknown label: person
# unknown label: person
# unknown label: pottedplant
# unknown label: person
# unknown label: person
# unknown label: crashedbottle
# unknown label: person
# unknown label: diningtable
# unknown label: chair
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: diningtable
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: diningtable
# unknown label: person
# unknown label: crashedbottle
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: person
# unknown label: diningtable
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: chair
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: crashedbottle
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: pottedplant
# unknown label: pottedplant
# unknown label: tvmonitor
# unknown label: crashedbottle
# unknown label: dog
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: diningtable
# unknown label: pottedplant
# unknown label: tvmonitor
# unknown label: tvmonitor
# unknown label: crashedbottle
# unknown label: diningtable
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: crashedbottle
# unknown label: crashedbottle
# unknown label: person
# unknown label: diningtable
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: chair
# unknown label: diningtable
# unknown label: diningtable
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: diningtable
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: person
# unknown label: person
# unknown label: diningtable
# unknown label: person
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: tvmonitor
# unknown label: tvmonitor
# unknown label: diningtable
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: pottedplant
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: chair
# unknown label: chair
# unknown label: pottedplant
# unknown label: crashedbottle
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: diningtable
# unknown label: diningtable
# unknown label: chair
# unknown label: person
# unknown label: person
# unknown label: chair
# unknown label: crashedbottle
# unknown label: crashedbottle
# unknown label: chair
# unknown label: tvmonitor
# unknown label: tvmonitor
# unknown label: crashedbottle
# unknown label: person
# unknown label: person
# unknown label: sofa
# unknown label: person
# unknown label: diningtable
# unknown label: pottedplant
# unknown label: pottedplant
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: diningtable
# unknown label: diningtable
# unknown label: tvmonitor
# unknown label: person
# unknown label: pottedplant
# unknown label: pottedplant
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: diningtable
# unknown label: person
# unknown label: diningtable
# unknown label: person
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: crashedbottle
# unknown label: crashedbottle
# unknown label: person
# unknown label: person
# unknown label: diningtable
# unknown label: diningtable
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: crashedbottle
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: chair
# unknown label: bicycle
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: diningtable
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: tvmonitor
# unknown label: chair
# unknown label: chair
# unknown label: diningtable
# unknown label: person
# unknown label: chair
# unknown label: diningtable
# unknown label: chair
# unknown label: chair
# unknown label: crashedbottle
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: diningtable
# unknown label: chair
# unknown label: chair
# unknown label: diningtable
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: tvmonitor
# unknown label: sofa
# unknown label: person
# unknown label: person
# unknown label: tvmonitor
# unknown label: chair
# unknown label: chair
# unknown label: sofa
# unknown label: pottedplant
# unknown label: pottedplant
# unknown label: pottedplant
# unknown label: pottedplant
# unknown label: pottedplant
# unknown label: pottedplant
# unknown label: pottedplant
# unknown label: chair
# unknown label: tvmonitor
# unknown label: pottedplant
# unknown label: crashedbottle
# unknown label: person
# unknown label: person
# unknown label: tvmonitor
# unknown label: person
# unknown label: person
# unknown label: bicycle
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: dog
# unknown label: diningtable
# unknown label: pottedplant
# unknown label: chair
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: sofa
# unknown label: chair
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: diningtable
# unknown label: diningtable
# unknown label: chair
# unknown label: chair
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: pottedplant
# unknown label: diningtable
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: person
# unknown label: chair
# unknown label: tvmonitor
# unknown label: tvmonitor
# unknown label: person
# unknown label: car
# unknown label: car
# unknown label: person
# unknown label: cat
# unknown label: person
# unknown label: diningtable
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: chair
# unknown label: sofa
# unknown label: diningtable
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: dog
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: car
# unknown label: sofa
# unknown label: chair
# unknown label: pottedplant
# unknown label: pottedplant
# unknown label: tvmonitor
# unknown label: tvmonitor
# unknown label: person
# unknown label: person
# unknown label: sofa
# unknown label: crashedbottle
# unknown label: diningtable
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: diningtable
# unknown label: diningtable
# unknown label: chair
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: diningtable
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: dog
# unknown label: chair
# unknown label: horse
# unknown label: person
# unknown label: car
# unknown label: crashedbottle
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: sheep
# unknown label: sheep
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: person
# unknown label: crashedbottle
# unknown label: pottedplant
# unknown label: pottedplant
# unknown label: pottedplant
# unknown label: person
# unknown label: diningtable
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: diningtable
# unknown label: sofa
# unknown label: chair
# unknown label: chair
# unknown label: chair
# unknown label: person
# unknown label: person
# unknown label: chair
# unknown label: cow
# unknown label: person

# %%
gt
# Out:
# {'0000001.jpg': array([[ 0.28186275,  0.38970588,  0.69178922,  0.61356209,  0.        ,
#           0.        ]]),
#  '0000002.jpg': array([[ 0.34007353,  0.14665033,  0.60569853,  0.85294118,  0.        ,
#           0.        ]]),
#  '0000003.jpg': array([[ 0.25398284,  0.32761438,  0.6317402 ,  0.85498366,  0.        ,
#           0.        ]]),
#  '0000004.jpg': array([[ 0.56617647,  0.41911765,  0.72242647,  0.74019608,  0.        ,
#           0.        ]]),
#  '0000005.jpg': array([[ 0.44791667,  0.38398693,  0.60723039,  0.79656863,  0.        ,
#           0.        ]]),
#  '0000006.jpg': array([[ 0.36795343,  0.35866013,  0.74142157,  0.8374183 ,  0.        ,
#           0.        ]]),
#  '0000007.jpg': array([[ 0.38082108,  0.36846405,  0.6216299 ,  0.76552288,  0.        ,
#           0.        ]]),
#  '0000008.jpg': array([[ 0.46844363,  0.34109477,  0.70036765,  0.74019608,  0.        ,
#           0.        ]]),
#  '0000009.jpg': array([[ 0.46109069,  0.32965686,  0.65533088,  0.70874183,  0.        ,
#           0.        ]]),
#  '0000010.jpg': array([[ 0.20588235,  0.3374183 ,  0.6495098 ,  0.61928105,  0.        ,
#           0.        ]]),
#  '0000011.jpg': array([[ 0.44515931,  0.31576797,  0.59528186,  0.73815359,  0.        ,
#           0.        ]]),
#  '0000012.jpg': array([[ 0.35171569,  0.27328431,  0.61305147,  0.79820261,  0.        ,
#           0.        ]]),
#  '0000013.jpg': array([[ 0.18106618,  0.51838235,  0.56464461,  0.74183007,  0.        ,
#           0.        ]]),
#  '0000014.jpg': array([[ 0.0379902 ,  0.34885621,  0.53707108,  0.55310458,  0.        ,
#           0.        ]]),
#  '0000015.jpg': array([[ 0.0379902 ,  0.34885621,  0.53553922,  0.54534314,  0.        ,
#           0.        ]]),
#  '0000016.jpg': array([[ 0.25398284,  0.38602941,  0.53400735,  0.50081699,  0.        ,
#           0.        ]]),
#  '0000017.jpg': array([[ 0.42340686,  0.51429739,  0.58241422,  0.64665033,  0.        ,
#           0.        ]]),
#  '0000018.jpg': array([[ 0.4129902 ,  0.47344771,  0.53982843,  0.82761438,  0.        ,
#           0.        ]]),
#  '0000019.jpg': array([[ 0.37663399,  0.47875817,  0.56617647,  0.82312092,  0.        ,
#           0.        ]]),
#  '0000020.jpg': array([[ 0.29044118,  0.16952614,  0.57189542,  0.31535948,  0.        ,
#           0.        ]]),
#  '0000021.jpg': array([[ 0.22181373,  0.16339869,  0.46691176,  0.25245098,  0.        ,
#           0.        ]]),
#  '0000022.jpg': array([[ 0.33986928,  0.11683007,  0.40727124,  0.29330065,  0.        ,
#           0.        ]]),
#  '0000023.jpg': array([[ 0.17361111,  0.59232026,  0.53553922,  0.7120098 ,  0.        ,
#           0.        ]]),
#  '0000024.jpg': array([[ 0.29932598,  0.26348039,  0.4028799 ,  0.57843137,  0.        ,
#           0.        ]]),
#  '0000028.jpg': array([[ 0.37806373,  0.64297386,  0.99356618,  0.98325163,  0.        ,
#           0.        ],
#         [ 0.32261029,  0.21078431,  0.55300245,  0.36070261,  0.        ,
#           0.        ]]),
#  '0000029.jpg': array([[ 0.34007353,  0.1875    ,  0.53125   ,  0.30637255,  0.        ,
#           0.        ]]),
#  '0000030.jpg': array([[ 0.32843137,  0.21854575,  0.66973039,  0.41707516,  0.        ,
#           0.        ]]),
#  '0000031.jpg': array([[ 0.37224265,  0.22834967,  0.55300245,  0.45792484,  0.        ,
#           0.        ]]),
#  '0000032.jpg': array([[ 0.34742647,  0.3374183 ,  0.47273284,  0.48120915,  0.        ,
#           0.        ]]),
#  '0000033.jpg': array([[ 0.40563725,  0.4248366 ,  0.52818627,  0.58251634,  0.        ,
#           0.        ]]),
#  '0000034.jpg': array([[ 0.5122549 ,  0.41503268,  0.67279412,  0.55147059,  0.        ,
#           0.        ]]),
#  '0000035.jpg': array([[ 0.48314951,  0.35294118,  0.57935049,  0.5494281 ,  0.        ,
#           0.        ]]),
#  '0000036.jpg': array([[ 0.39123775,  0.50857843,  0.54871324,  0.57271242,  0.        ,
#           0.        ]]),
#  '0000037.jpg': array([[ 0.43504902,  0.54738562,  0.58946078,  0.62908497,  0.        ,
#           0.        ]]),
#  '0000038.jpg': array([[ 0.44362745,  0.32761438,  0.51654412,  0.55147059,  0.        ,
#           0.        ]]),
#  '0000039.jpg': array([[ 0.22487745,  0.21078431,  0.47150735,  0.37254902,  0.        ,
#           0.        ]]),
#  '0000040.jpg': array([[ 0.35018382,  0.25939542,  0.57352941,  0.43668301,  0.        ,
#           0.        ]]),
#  '0000041.jpg': array([[ 0.37959559,  0.20138889,  0.54289216,  0.44035948,  0.        ,
#           0.        ]]),
#  '0000042.jpg': array([[ 0.20863971,  0.54534314,  0.44515931,  0.66013072,  0.        ,
#           0.        ]]),
#  '0000043.jpg': array([[ 0.28186275,  0.4620098 ,  0.53125   ,  0.61764706,  0.        ,
#           0.        ]]),
#  '0000044.jpg': array([[ 0.30514706,  0.45220588,  0.5033701 ,  0.7128268 ,  0.        ,
#           0.        ]]),
#  '0000046.jpg': array([[ 0.34589461,  0.51838235,  0.5692402 ,  0.67769608,  0.        ,
#           0.        ]]),
#  '0000047.jpg': array([[ 0.28768382,  0.5629085 ,  0.49172794,  0.68382353,  0.        ,
#           0.        ]]),
#  '0000048.jpg': array([[ 0.2935049 ,  0.54370915,  0.48897059,  0.64869281,  0.        ,
#           0.        ]]),
#  '0000049.jpg': array([[ 0.34589461,  0.4873366 ,  0.51654412,  0.6000817 ,  0.        ,
#           0.        ]]),
#  '0000050.jpg': array([[ 0.1752451 ,  0.58210784,  0.43178105,  0.67565359,  0.        ,
#           0.        ]]),
#  '0000051.jpg': array([[ 0.32843137,  0.57802288,  0.58374183,  0.66094771,  0.        ,
#           0.        ]]),
#  '0000052.jpg': array([[ 0.34885621,  0.53390523,  0.59844771,  0.68586601,  0.        ,
#           0.        ]]),
#  '0000053.jpg': array([[ 0.35334967,  0.49305556,  0.58496732,  0.59844771,  0.        ,
#           0.        ]]),
#  '0000054.jpg': array([[ 0.52818627,  0.53104575,  0.74550654,  0.59517974,  0.        ,
#           0.        ]]),
#  '000050.jpg': array([[ 0.81      ,  0.408     ,  0.986     ,  0.68      ,  0.        ,
#           0.        ],
#         [ 0.55      ,  0.344     ,  0.624     ,  0.45333333,  0.        ,
#           0.        ],
#         [ 0.72      ,  0.512     ,  0.762     ,  0.70666667,  1.        ,
#           0.        ],
#         [ 0.798     ,  0.48266667,  0.844     ,  0.62666667,  1.        ,
#           0.        ],
#         [ 0.54      ,  0.48      ,  0.582     ,  0.65866667,  1.        ,
#           0.        ],
#         [ 0.588     ,  0.46933333,  0.624     ,  0.64266667,  1.        ,
#           0.        ],
#         [ 0.136     ,  0.256     ,  0.586     ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.002     ,  0.18933333,  0.174     ,  0.88533333,  0.        ,
#           0.        ],
#         [ 0.37      ,  0.18133333,  0.518     ,  0.52533333,  0.        ,
#           0.        ],
#         [ 0.572     ,  0.17066667,  0.812     ,  0.63466667,  0.        ,
#           0.        ]]),
#  '000170.jpg': array([[ 0.174     ,  0.26666667,  0.218     ,  0.44      ,  1.        ,
#           0.        ],
#         [ 0.082     ,  0.304     ,  0.146     ,  0.48266667,  1.        ,
#           0.        ],
#         [ 0.648     ,  0.39466667,  0.704     ,  0.54933333,  1.        ,
#           0.        ],
#         [ 0.852     ,  0.41866667,  0.886     ,  0.52      ,  1.        ,
#           0.        ],
#         [ 0.006     ,  0.24266667,  0.086     ,  0.54933333,  0.        ,
#           0.        ],
#         [ 0.008     ,  0.07466667,  0.922     ,  0.992     ,  0.        ,
#           0.        ]]),
#  '000200.jpg': array([[ 0.056     ,  0.07630522,  0.206     ,  0.67068273,  0.        ,
#           0.        ],
#         [ 0.032     ,  0.21686747,  0.356     ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.294     ,  0.09236948,  0.49      ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.454     ,  0.07630522,  0.8       ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.782     ,  0.05220884,  1.        ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.728     ,  0.85140562,  0.778     ,  1.        ,  1.        ,
#           0.        ],
#         [ 0.462     ,  0.58232932,  0.52      ,  0.84337349,  1.        ,
#           0.        ]]),
#  '000222.jpg': array([[ 0.356     ,  0.576     ,  0.606     ,  0.86933333,  0.        ,
#           0.        ],
#         [ 0.5       ,  0.632     ,  0.724     ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.228     ,  0.62933333,  0.454     ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.442     ,  0.59466667,  0.47      ,  0.70933333,  1.        ,
#           0.        ],
#         [ 0.468     ,  0.568     ,  0.49      ,  0.68266667,  1.        ,
#           0.        ],
#         [ 0.682     ,  0.39733333,  0.752     ,  0.576     ,  0.        ,
#           0.        ],
#         [ 0.316     ,  0.50933333,  0.37      ,  0.58933333,  0.        ,
#           0.        ],
#         [ 0.318     ,  0.472     ,  0.412     ,  0.61333333,  0.        ,
#           0.        ],
#         [ 0.504     ,  0.47466667,  0.622     ,  0.608     ,  0.        ,
#           0.        ],
#         [ 0.582     ,  0.51466667,  0.664     ,  0.64266667,  0.        ,
#           0.        ],
#         [ 0.636     ,  0.55733333,  0.746     ,  0.88      ,  0.        ,
#           0.        ],
#         [ 0.2       ,  0.54933333,  0.34      ,  0.912     ,  0.        ,
#           0.        ],
#         [ 0.888     ,  0.75466667,  1.        ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.732     ,  0.648     ,  0.788     ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.734     ,  0.57866667,  0.78      ,  0.71733333,  0.        ,
#           0.        ]]),
#  '000224.jpg': array([[ 0.072     ,  0.424     ,  0.44      ,  0.89866667,  0.        ,
#           0.        ],
#         [ 0.802     ,  0.65333333,  1.        ,  1.        ,  1.        ,
#           0.        ]]),
#  '000229.jpg': array([[ 0.19      ,  0.55733333,  0.842     ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.798     ,  0.584     ,  0.972     ,  0.98933333,  0.        ,
#           0.        ],
#         [ 0.682     ,  0.42933333,  0.864     ,  0.79466667,  0.        ,
#           0.        ],
#         [ 0.768     ,  0.36      ,  0.874     ,  0.54133333,  0.        ,
#           0.        ],
#         [ 0.478     ,  0.34933333,  0.674     ,  0.56266667,  0.        ,
#           0.        ],
#         [ 0.296     ,  0.384     ,  0.422     ,  0.68      ,  0.        ,
#           0.        ],
#         [ 0.162     ,  0.42666667,  0.394     ,  0.872     ,  0.        ,
#           0.        ],
#         [ 0.004     ,  0.50133333,  0.214     ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.708     ,  0.80266667,  0.764     ,  0.98666667,  1.        ,
#           0.        ],
#         [ 0.078     ,  0.33066667,  0.108     ,  0.42933333,  1.        ,
#           0.        ],
#         [ 0.922     ,  0.504     ,  1.        ,  0.752     ,  0.        ,
#           0.        ]]),
#  '000250.jpg': array([[ 0.002     ,  0.45333333,  0.948     ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.194     ,  0.33066667,  0.3       ,  0.792     ,  1.        ,
#           0.        ]]),
#  '000269.jpg': array([[ 0.37      ,  0.79518072,  0.41      ,  0.96385542,  1.        ,
#           0.        ],
#         [ 0.596     ,  0.73795181,  0.652     ,  0.93975904,  1.        ,
#           0.        ],
#         [ 0.48      ,  0.00301205,  0.522     ,  0.07831325,  1.        ,
#           0.        ],
#         [ 0.314     ,  0.00301205,  0.348     ,  0.0813253 ,  1.        ,
#           0.        ],
#         [ 0.278     ,  0.00301205,  0.31      ,  0.08433735,  1.        ,
#           0.        ],
#         [ 0.454     ,  0.1686747 ,  0.994     ,  0.64156627,  0.        ,
#           0.        ],
#         [ 0.182     ,  0.17771084,  0.49      ,  0.78614458,  0.        ,
#           0.        ],
#         [ 0.074     ,  0.40361446,  0.406     ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.452     ,  0.22590361,  0.826     ,  0.8253012 ,  0.        ,
#           0.        ],
#         [ 0.516     ,  0.34337349,  0.954     ,  1.        ,  0.        ,
#           0.        ]]),
#  '000344.jpg': array([[ 0.23733333,  0.004     ,  0.81866667,  0.882     ,  1.        ,
#           0.        ]]),
#  '000367.jpg': array([[ 0.454     ,  0.33066667,  0.542     ,  0.70666667,  1.        ,
#           0.        ],
#         [ 0.662     ,  0.32533333,  0.78      ,  0.944     ,  1.        ,
#           0.        ],
#         [ 0.788     ,  0.488     ,  0.844     ,  0.90666667,  1.        ,
#           0.        ],
#         [ 0.57      ,  0.33333333,  0.652     ,  0.90666667,  1.        ,
#           0.        ],
#         [ 0.86      ,  0.49066667,  1.        ,  0.61066667,  0.        ,
#           0.        ],
#         [ 0.004     ,  0.68      ,  1.        ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.348     ,  0.176     ,  0.59      ,  0.70666667,  0.        ,
#           0.        ]]),
#  '000381.jpg': array([[ 0.016     ,  0.368     ,  1.        ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.21066667,  0.314     ,  0.384     ,  0.532     ,  0.        ,
#           0.        ],
#         [ 0.00266667,  0.398     ,  0.21333333,  0.706     ,  0.        ,
#           0.        ],
#         [ 0.00266667,  0.764     ,  0.296     ,  0.998     ,  0.        ,
#           0.        ],
#         [ 0.41333333,  0.016     ,  0.464     ,  0.074     ,  1.        ,
#           0.        ]]),
#  '000498.jpg': array([[ 0.01840491,  0.01      ,  0.5398773 ,  0.406     ,  1.        ,
#           0.        ],
#         [ 0.34969325,  0.512     ,  0.61656442,  0.992     ,  0.        ,
#           0.        ]]),
#  '000531.jpg': array([[ 0.054     ,  0.112     ,  0.41      ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.3       ,  0.08266667,  0.724     ,  0.99466667,  0.        ,
#           0.        ],
#         [ 0.732     ,  0.152     ,  1.        ,  0.82933333,  0.        ,
#           0.        ],
#         [ 0.738     ,  0.43466667,  0.858     ,  0.888     ,  1.        ,
#           0.        ],
#         [ 0.458     ,  0.47466667,  0.562     ,  0.76266667,  1.        ,
#           0.        ]]),
#  '000559.jpg': array([[ 0.072     ,  0.67567568,  0.158     ,  0.95675676,  1.        ,
#           0.        ],
#         [ 0.32      ,  0.07027027,  0.742     ,  0.65135135,  0.        ,
#           0.        ]]),
#  '000564.jpg': array([[ 0.172     ,  0.45045045,  1.        ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.06      ,  0.26726727,  0.094     ,  0.33933934,  1.        ,
#           0.        ],
#         [ 0.086     ,  0.31831832,  0.116     ,  0.44144144,  1.        ,
#           0.        ],
#         [ 0.012     ,  0.30930931,  0.038     ,  0.42642643,  1.        ,
#           0.        ],
#         [ 0.324     ,  0.38738739,  0.448     ,  0.55555556,  0.        ,
#           0.        ],
#         [ 0.512     ,  0.36636637,  0.624     ,  0.51951952,  0.        ,
#           0.        ],
#         [ 0.864     ,  0.34834835,  0.99      ,  0.53453453,  0.        ,
#           0.        ],
#         [ 0.732     ,  0.44744745,  0.958     ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.462     ,  0.48948949,  0.784     ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.002     ,  0.4954955 ,  0.324     ,  1.        ,  0.        ,
#           0.        ]]),
#  '000684.jpg': array([[ 0.33066667,  0.392     ,  0.67466667,  0.61      ,  0.        ,
#           0.        ],
#         [ 0.00533333,  0.61      ,  0.17866667,  0.69      ,  0.        ,
#           0.        ],
#         [ 0.13866667,  0.224     ,  0.24266667,  0.366     ,  0.        ,
#           0.        ],
#         [ 0.00266667,  0.392     ,  0.31466667,  0.644     ,  0.        ,
#           0.        ],
#         [ 0.144     ,  0.342     ,  0.20533333,  0.444     ,  1.        ,
#           0.        ],
#         [ 0.20533333,  0.202     ,  0.64266667,  0.628     ,  0.        ,
#           0.        ],
#         [ 0.57866667,  0.098     ,  0.784     ,  0.608     ,  0.        ,
#           0.        ],
#         [ 0.76      ,  0.044     ,  0.96266667,  0.732     ,  0.        ,
#           0.        ],
#         [ 0.792     ,  0.006     ,  1.        ,  0.738     ,  0.        ,
#           0.        ]]),
#  '000726.jpg': array([[ 0.036     ,  0.62762763,  0.448     ,  0.88588589,  1.        ,
#           0.        ],
#         [ 0.306     ,  0.13513514,  0.548     ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.14      ,  0.22522523,  0.998     ,  1.        ,  0.        ,
#           0.        ]]),
#  '000753.jpg': array([[ 0.328     ,  0.50133333,  0.858     ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.422     ,  0.304     ,  0.482     ,  0.52266667,  1.        ,
#           0.        ],
#         [ 0.53      ,  0.61066667,  0.576     ,  0.78933333,  1.        ,
#           0.        ],
#         [ 0.528     ,  0.528     ,  0.568     ,  0.66133333,  1.        ,
#           0.        ],
#         [ 0.526     ,  0.264     ,  0.704     ,  0.60533333,  0.        ,
#           0.        ],
#         [ 0.668     ,  0.28      ,  0.86      ,  0.67733333,  0.        ,
#           0.        ],
#         [ 0.702     ,  0.264     ,  1.        ,  0.99466667,  0.        ,
#           0.        ],
#         [ 0.256     ,  0.26933333,  0.384     ,  0.57066667,  0.        ,
#           0.        ],
#         [ 0.11      ,  0.288     ,  0.378     ,  0.99466667,  0.        ,
#           0.        ]]),
#  '000865.jpg': array([[ 0.6       ,  0.44533333,  0.794     ,  0.71466667,  0.        ,
#           0.        ],
#         [ 0.814     ,  0.44533333,  0.93      ,  0.672     ,  0.        ,
#           0.        ],
#         [ 0.688     ,  0.45866667,  0.828     ,  0.72533333,  0.        ,
#           0.        ],
#         [ 0.756     ,  0.45333333,  0.882     ,  0.696     ,  0.        ,
#           0.        ],
#         [ 0.42      ,  0.66933333,  0.664     ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.146     ,  0.42666667,  0.288     ,  0.568     ,  0.        ,
#           0.        ],
#         [ 0.668     ,  0.42666667,  0.688     ,  0.48533333,  1.        ,
#           0.        ],
#         [ 0.38      ,  0.272     ,  0.674     ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.006     ,  0.344     ,  0.248     ,  0.784     ,  0.        ,
#           0.        ]]),
#  '000929.jpg': array([[ 0.002     ,  0.17333333,  1.        ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.522     ,  0.17066667,  0.59      ,  0.536     ,  1.        ,
#           0.        ],
#         [ 0.506     ,  0.06133333,  0.552     ,  0.25333333,  1.        ,
#           0.        ],
#         [ 0.024     ,  0.19733333,  0.144     ,  0.37866667,  0.        ,
#           0.        ],
#         [ 0.788     ,  0.22666667,  0.956     ,  0.464     ,  0.        ,
#           0.        ],
#         [ 0.788     ,  0.136     ,  0.924     ,  0.35733333,  0.        ,
#           0.        ]]),
#  '000951.jpg': array([[ 0.452     ,  0.19466667,  0.49      ,  0.33866667,  1.        ,
#           0.        ]]),
#  '000999.jpg': array([[ 0.62133333,  0.634     ,  0.77066667,  0.81      ,  1.        ,
#           0.        ],
#         [ 0.00533333,  0.032     ,  0.74666667,  1.        ,  0.        ,
#           0.        ]]),
#  '001045.jpg': array([[ 0.57066667,  0.004     ,  0.872     ,  0.552     ,  1.        ,
#           0.        ]]),
#  '001185.jpg': array([[ 0.394     ,  0.53066667,  0.578     ,  0.86133333,  0.        ,
#           0.        ],
#         [ 0.156     ,  0.208     ,  0.578     ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.408     ,  0.59466667,  1.        ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.904     ,  0.34933333,  1.        ,  0.67466667,  1.        ,
#           0.        ]]),
#  '001229.jpg': array([[ 0.416     ,  0.24266667,  0.826     ,  0.57066667,  1.        ,
#           0.        ],
#         [ 0.03      ,  0.2       ,  0.858     ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.696     ,  0.41866667,  1.        ,  1.        ,  0.        ,
#           0.        ]]),
#  '001272.jpg': array([[ 0.364     ,  0.21014493,  0.484     ,  0.48792271,  1.        ,
#           0.        ],
#         [ 0.362     ,  0.37198068,  0.6       ,  0.63768116,  1.        ,
#           0.        ],
#         [ 0.206     ,  0.0531401 ,  0.938     ,  1.        ,  0.        ,
#           0.        ]]),
#  '001292.jpg': array([[ 0.726     ,  0.48      ,  0.824     ,  0.91733333,  1.        ,
#           0.        ],
#         [ 0.122     ,  0.168     ,  0.616     ,  0.90133333,  0.        ,
#           0.        ],
#         [ 0.484     ,  0.12      ,  0.532     ,  0.27466667,  0.        ,
#           0.        ],
#         [ 0.372     ,  0.184     ,  0.43      ,  0.23733333,  0.        ,
#           0.        ],
#         [ 0.308     ,  0.16533333,  0.45      ,  0.25866667,  0.        ,
#           0.        ]]),
#  '001346.jpg': array([[ 0.618     ,  0.42358079,  0.712     ,  1.        ,  1.        ,
#           0.        ],
#         [ 0.44      ,  0.01746725,  0.894     ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.014     ,  0.00436681,  0.524     ,  0.99563319,  0.        ,
#           0.        ]]),
#  '001393.jpg': array([[ 0.122     ,  0.51733333,  0.65      ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.004     ,  0.51733333,  0.156     ,  0.99733333,  0.        ,
#           0.        ],
#         [ 0.578     ,  0.37333333,  0.96      ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.582     ,  0.34666667,  0.8       ,  0.94666667,  0.        ,
#           0.        ],
#         [ 0.394     ,  0.33066667,  0.57      ,  0.53066667,  0.        ,
#           0.        ],
#         [ 0.03      ,  0.34933333,  0.266     ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.52      ,  0.43733333,  0.56      ,  0.568     ,  1.        ,
#           0.        ],
#         [ 0.464     ,  0.44      ,  0.492     ,  0.53866667,  1.        ,
#           0.        ],
#         [ 0.426     ,  0.43733333,  0.46      ,  0.55733333,  1.        ,
#           0.        ],
#         [ 0.412     ,  0.46933333,  0.442     ,  0.576     ,  1.        ,
#           0.        ],
#         [ 0.392     ,  0.504     ,  0.42      ,  0.61866667,  1.        ,
#           0.        ],
#         [ 0.268     ,  0.48      ,  0.5       ,  1.        ,  0.        ,
#           0.        ]]),
#  '001408.jpg': array([[ 0.34234234,  0.49      ,  0.53453453,  0.896     ,  1.        ,
#           0.        ],
#         [ 0.16816817,  0.214     ,  0.69069069,  0.774     ,  0.        ,
#           0.        ],
#         [ 0.06006006,  0.136     ,  0.15015015,  0.334     ,  1.        ,
#           0.        ],
#         [ 0.63063063,  0.002     ,  1.        ,  0.216     ,  0.        ,
#           0.        ],
#         [ 0.25225225,  0.174     ,  1.        ,  0.732     ,  0.        ,
#           0.        ],
#         [ 0.35735736,  0.002     ,  0.55255255,  0.26      ,  0.        ,
#           0.        ]]),
#  '001444.jpg': array([[ 0.182     ,  0.69866667,  0.654     ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.452     ,  0.52266667,  0.774     ,  0.872     ,  0.        ,
#           0.        ],
#         [ 0.736     ,  0.496     ,  0.856     ,  0.64266667,  0.        ,
#           0.        ],
#         [ 0.058     ,  0.55466667,  0.116     ,  0.69066667,  1.        ,
#           0.        ],
#         [ 0.328     ,  0.37333333,  0.438     ,  0.736     ,  0.        ,
#           0.        ],
#         [ 0.286     ,  0.40533333,  0.352     ,  0.50933333,  0.        ,
#           0.        ],
#         [ 0.224     ,  0.408     ,  0.286     ,  0.504     ,  0.        ,
#           0.        ]]),
#  '001451.jpg': array([[ 0.006     ,  0.70958084,  1.        ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.758     ,  0.59580838,  0.838     ,  0.79041916,  1.        ,
#           0.        ],
#         [ 0.328     ,  0.47005988,  0.442     ,  0.87724551,  1.        ,
#           0.        ],
#         [ 0.484     ,  0.35628743,  0.772     ,  0.73053892,  0.        ,
#           0.        ],
#         [ 0.194     ,  0.30239521,  0.442     ,  0.75149701,  0.        ,
#           0.        ],
#         [ 0.024     ,  0.45508982,  0.104     ,  0.56586826,  0.        ,
#           0.        ]]),
#  '001465.jpg': array([[ 0.662     ,  0.576     ,  0.964     ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.002     ,  0.752     ,  0.312     ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.562     ,  0.512     ,  0.658     ,  0.78933333,  0.        ,
#           0.        ],
#         [ 0.48      ,  0.50133333,  0.564     ,  0.76533333,  0.        ,
#           0.        ],
#         [ 0.15      ,  0.55466667,  0.314     ,  0.90133333,  0.        ,
#           0.        ],
#         [ 0.04      ,  0.62133333,  0.172     ,  0.97333333,  0.        ,
#           0.        ],
#         [ 0.002     ,  0.624     ,  0.242     ,  0.94933333,  0.        ,
#           0.        ],
#         [ 0.07      ,  0.56      ,  0.092     ,  0.63733333,  1.        ,
#           0.        ]]),
#  '001490.jpg': array([[ 0.398     ,  0.31531532,  0.764     ,  0.97897898,  0.        ,
#           0.        ],
#         [ 0.592     ,  0.33333333,  0.652     ,  0.51351351,  1.        ,
#           0.        ],
#         [ 0.552     ,  0.32132132,  0.606     ,  0.4984985 ,  1.        ,
#           0.        ]]),
#  '001493.jpg': array([[ 0.778     ,  0.20533333,  0.95      ,  0.76533333,  0.        ,
#           0.        ],
#         [ 0.848     ,  0.24      ,  1.        ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.366     ,  0.21866667,  0.624     ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.07      ,  0.088     ,  0.444     ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.058     ,  0.59466667,  0.088     ,  0.72      ,  1.        ,
#           0.        ]]),
#  '001522.jpg': array([[ 0.618     ,  0.12266667,  0.754     ,  0.64266667,  1.        ,
#           0.        ],
#         [ 0.434     ,  0.26666667,  0.544     ,  0.65866667,  1.        ,
#           0.        ]]),
#  '001537.jpg': array([[ 0.828     ,  0.26204819,  1.        ,  0.73192771,  0.        ,
#           0.        ],
#         [ 0.726     ,  0.72590361,  1.        ,  0.94277108,  0.        ,
#           0.        ],
#         [ 0.208     ,  0.04819277,  0.734     ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.77      ,  0.63855422,  0.816     ,  0.8373494 ,  1.        ,
#           0.        ]]),
#  '001563.jpg': array([[ 0.024     ,  0.6036036 ,  0.77      ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.688     ,  0.33033033,  0.892     ,  0.81981982,  0.        ,
#           0.        ],
#         [ 0.524     ,  0.25825826,  0.72      ,  0.5975976 ,  0.        ,
#           0.        ],
#         [ 0.26      ,  0.37537538,  0.4       ,  0.60660661,  0.        ,
#           0.        ],
#         [ 0.424     ,  0.39339339,  0.576     ,  0.60660661,  0.        ,
#           0.        ],
#         [ 0.01      ,  0.33033033,  0.264     ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.144     ,  0.5045045 ,  0.19      ,  0.71171171,  1.        ,
#           0.        ],
#         [ 0.218     ,  0.53153153,  0.252     ,  0.65165165,  1.        ,
#           0.        ],
#         [ 0.254     ,  0.52252252,  0.286     ,  0.63063063,  1.        ,
#           0.        ],
#         [ 0.522     ,  0.52252252,  0.556     ,  0.61261261,  1.        ,
#           0.        ],
#         [ 0.796     ,  0.57357357,  0.976     ,  0.84984985,  0.        ,
#           0.        ]]),
#  '001580.jpg': array([[ 0.418     ,  0.17866667,  0.866     ,  0.90933333,  0.        ,
#           0.        ],
#         [ 0.006     ,  0.256     ,  0.378     ,  0.89866667,  0.        ,
#           0.        ],
#         [ 0.006     ,  0.416     ,  0.966     ,  0.98133333,  0.        ,
#           0.        ],
#         [ 0.002     ,  0.21866667,  0.086     ,  0.728     ,  0.        ,
#           0.        ],
#         [ 0.334     ,  0.59733333,  0.42      ,  1.        ,  1.        ,
#           0.        ],
#         [ 0.276     ,  0.672     ,  0.39      ,  1.        ,  1.        ,
#           0.        ]]),
#  '001590.jpg': array([[ 0.39466667,  0.446     ,  0.616     ,  0.9       ,  1.        ,
#           0.        ],
#         [ 0.808     ,  0.08      ,  1.        ,  0.648     ,  0.        ,
#           0.        ]]),
#  '001673.jpg': array([[ 0.072     ,  0.29333333,  0.88      ,  0.85066667,  0.        ,
#           0.        ],
#         [ 0.836     ,  0.00266667,  0.964     ,  0.34933333,  1.        ,
#           0.        ]]),
#  '001682.jpg': array([[ 0.006     ,  0.25825826,  0.744     ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.068     ,  0.03303303,  1.        ,  0.99099099,  0.        ,
#           0.        ],
#         [ 0.604     ,  0.18018018,  1.        ,  0.94894895,  1.        ,
#           0.        ]]),
#  '001754.jpg': array([[ 0.58666667,  0.608     ,  0.73866667,  0.972     ,  1.        ,
#           0.        ],
#         [ 0.04      ,  0.108     ,  0.73333333,  0.988     ,  0.        ,
#           0.        ],
#         [ 0.74933333,  0.292     ,  0.99733333,  0.788     ,  0.        ,
#           0.        ],
#         [ 0.01066667,  0.264     ,  0.14666667,  0.348     ,  0.        ,
#           0.        ]]),
#  '001756.jpg': array([[ 0.18933333,  0.826     ,  1.        ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.92266667,  0.744     ,  1.        ,  0.852     ,  0.        ,
#           0.        ],
#         [ 0.352     ,  0.606     ,  0.46666667,  0.894     ,  1.        ,
#           0.        ],
#         [ 0.68266667,  0.208     ,  0.968     ,  0.83      ,  0.        ,
#           0.        ],
#         [ 0.01333333,  0.066     ,  0.69866667,  0.906     ,  0.        ,
#           0.        ],
#         [ 0.06933333,  0.886     ,  0.28533333,  1.        ,  0.        ,
#           0.        ]]),
#  '001777.jpg': array([[ 0.79      ,  0.13772455,  0.886     ,  0.59281437,  1.        ,
#           0.        ],
#         [ 0.86      ,  0.17065868,  1.        ,  0.51197605,  0.        ,
#           0.        ],
#         [ 0.128     ,  0.17365269,  0.348     ,  0.35628743,  0.        ,
#           0.        ],
#         [ 0.01      ,  0.29640719,  0.994     ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.326     ,  0.06586826,  0.618     ,  0.33832335,  0.        ,
#           0.        ],
#         [ 0.186     ,  0.00299401,  0.388     ,  0.17964072,  0.        ,
#           0.        ],
#         [ 0.796     ,  0.34131737,  0.868     ,  0.65568862,  1.        ,
#           0.        ]]),
#  '001843.jpg': array([[ 0.598     ,  0.49333333,  0.646     ,  0.736     ,  1.        ,
#           0.        ],
#         [ 0.504     ,  0.09333333,  0.89      ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.124     ,  0.04533333,  0.546     ,  1.        ,  0.        ,
#           0.        ]]),
#  '001963.jpg': array([[ 0.314     ,  0.22133333,  0.674     ,  0.82666667,  0.        ,
#           0.        ],
#         [ 0.002     ,  0.27466667,  0.196     ,  0.89866667,  0.        ,
#           0.        ],
#         [ 0.492     ,  0.63466667,  0.552     ,  0.91733333,  1.        ,
#           0.        ],
#         [ 0.02      ,  0.66133333,  0.08      ,  0.94666667,  1.        ,
#           0.        ],
#         [ 0.486     ,  0.344     ,  0.544     ,  0.62933333,  1.        ,
#           0.        ],
#         [ 0.484     ,  0.05066667,  0.544     ,  0.33066667,  1.        ,
#           0.        ],
#         [ 0.01      ,  0.75466667,  0.998     ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.164     ,  0.624     ,  0.406     ,  0.86666667,  0.        ,
#           0.        ],
#         [ 0.184     ,  0.52266667,  0.342     ,  0.85066667,  0.        ,
#           0.        ]]),
#  '001970.jpg': array([[ 0.278     ,  0.00533333,  0.716     ,  0.94666667,  1.        ,
#           0.        ]]),
#  '002030.jpg': array([[ 0.202     ,  0.40266667,  0.302     ,  0.50133333,  0.        ,
#           0.        ],
#         [ 0.366     ,  0.4       ,  0.452     ,  0.53866667,  0.        ,
#           0.        ],
#         [ 0.874     ,  0.00266667,  1.        ,  0.99733333,  0.        ,
#           0.        ],
#         [ 0.002     ,  0.18133333,  0.414     ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.398     ,  0.26933333,  0.766     ,  0.81066667,  0.        ,
#           0.        ],
#         [ 0.632     ,  0.29333333,  0.936     ,  0.656     ,  0.        ,
#           0.        ],
#         [ 0.618     ,  0.68266667,  0.73      ,  1.        ,  1.        ,
#           0.        ],
#         [ 0.548     ,  0.61066667,  0.626     ,  0.85866667,  1.        ,
#           0.        ],
#         [ 0.944     ,  0.53066667,  0.986     ,  0.70666667,  1.        ,
#           0.        ],
#         [ 0.004     ,  0.632     ,  1.        ,  1.        ,  0.        ,
#           0.        ]]),
#  '002098.jpg': array([[ 0.766     ,  0.05866667,  0.936     ,  0.55733333,  1.        ,
#           0.        ],
#         [ 0.348     ,  0.01333333,  0.478     ,  0.54666667,  1.        ,
#           0.        ]]),
#  '002112.jpg': array([[ 0.36266667,  0.004     ,  1.        ,  1.        ,  1.        ,
#           0.        ]]),
#  '002139.jpg': array([[ 0.485,  0.002,  1.   ,  0.676,  1.   ,  0.   ]]),
#  '002221.jpg': array([[ 0.39466667,  0.116     ,  1.        ,  0.906     ,  0.        ,
#           0.        ],
#         [ 0.56533333,  0.038     ,  0.976     ,  0.2       ,  0.        ,
#           0.        ],
#         [ 0.00266667,  0.038     ,  0.368     ,  0.562     ,  0.        ,
#           0.        ],
#         [ 0.00266667,  0.148     ,  0.13066667,  0.632     ,  0.        ,
#           0.        ],
#         [ 0.31466667,  0.044     ,  1.        ,  0.458     ,  0.        ,
#           0.        ],
#         [ 0.47733333,  0.004     ,  0.52      ,  0.102     ,  1.        ,
#           0.        ]]),
#  '002226.jpg': array([[ 0.544     ,  0.07807808,  0.562     ,  0.12612613,  1.        ,
#           0.        ],
#         [ 0.568     ,  0.07807808,  0.586     ,  0.12312312,  1.        ,
#           0.        ],
#         [ 0.66      ,  0.03303303,  0.696     ,  0.19219219,  1.        ,
#           0.        ],
#         [ 0.632     ,  0.04504505,  0.664     ,  0.16816817,  1.        ,
#           0.        ],
#         [ 0.606     ,  0.04804805,  0.632     ,  0.14114114,  1.        ,
#           0.        ],
#         [ 0.582     ,  0.05705706,  0.606     ,  0.15315315,  1.        ,
#           0.        ],
#         [ 0.55      ,  0.06606607,  0.582     ,  0.17117117,  1.        ,
#           0.        ],
#         [ 0.526     ,  0.07207207,  0.55      ,  0.20720721,  1.        ,
#           0.        ],
#         [ 0.498     ,  0.07507508,  0.53      ,  0.21021021,  1.        ,
#           0.        ],
#         [ 0.96      ,  0.56456456,  1.        ,  0.69369369,  1.        ,
#           0.        ],
#         [ 0.934     ,  0.55855856,  0.97      ,  0.75975976,  1.        ,
#           0.        ],
#         [ 0.896     ,  0.55255255,  0.936     ,  0.75975976,  1.        ,
#           0.        ],
#         [ 0.856     ,  0.55855856,  0.894     ,  0.75675676,  1.        ,
#           0.        ],
#         [ 0.83      ,  0.54354354,  0.864     ,  0.72672673,  1.        ,
#           0.        ],
#         [ 0.196     ,  0.13813814,  1.        ,  1.        ,  0.        ,
#           0.        ]]),
#  '002253.jpg': array([[ 0.028     ,  0.04415584,  0.958     ,  0.82857143,  0.        ,
#           0.        ],
#         [ 0.486     ,  0.32467532,  0.56      ,  0.4961039 ,  1.        ,
#           0.        ],
#         [ 0.388     ,  0.33246753,  0.486     ,  0.48831169,  1.        ,
#           0.        ]]),
#  '002287.jpg': array([[ 0.534     ,  0.304     ,  0.654     ,  0.69333333,  1.        ,
#           0.        ],
#         [ 0.022     ,  0.17333333,  0.932     ,  0.85066667,  0.        ,
#           0.        ],
#         [ 0.002     ,  0.00266667,  1.        ,  1.        ,  0.        ,
#           0.        ]]),
#  '002350.jpg': array([[ 0.22933333,  0.006     ,  0.784     ,  1.        ,  1.        ,
#           0.        ]]),
#  '002404.jpg': array([[ 0.704     ,  0.18666667,  0.778     ,  0.44533333,  1.        ,
#           0.        ],
#         [ 0.788     ,  0.17866667,  0.908     ,  0.584     ,  0.        ,
#           0.        ],
#         [ 0.186     ,  0.144     ,  0.268     ,  0.408     ,  0.        ,
#           0.        ],
#         [ 0.002     ,  0.31466667,  0.098     ,  0.81333333,  0.        ,
#           0.        ],
#         [ 0.004     ,  0.21866667,  1.        ,  1.        ,  0.        ,
#           0.        ]]),
#  '002442.jpg': array([[ 0.008     ,  0.042     ,  1.        ,  0.994     ,  0.        ,
#           0.        ],
#         [ 0.09333333,  0.018     ,  0.256     ,  0.238     ,  0.        ,
#           0.        ],
#         [ 0.22666667,  0.01      ,  0.31466667,  0.162     ,  0.        ,
#           0.        ],
#         [ 0.64      ,  0.024     ,  0.70933333,  0.102     ,  0.        ,
#           0.        ],
#         [ 0.66933333,  0.082     ,  0.73333333,  0.15      ,  0.        ,
#           0.        ],
#         [ 0.70933333,  0.058     ,  0.83466667,  0.182     ,  0.        ,
#           0.        ],
#         [ 0.73333333,  0.132     ,  0.832     ,  0.24      ,  0.        ,
#           0.        ],
#         [ 0.79466667,  0.112     ,  0.976     ,  0.276     ,  0.        ,
#           0.        ],
#         [ 0.81866667,  0.16      ,  1.        ,  0.384     ,  0.        ,
#           0.        ],
#         [ 0.488     ,  0.002     ,  0.53333333,  0.07      ,  1.        ,
#           0.        ],
#         [ 0.464     ,  0.136     ,  0.55733333,  0.396     ,  1.        ,
#           0.        ]]),
#  '002444.jpg': array([[ 0.576     ,  0.256     ,  0.83      ,  0.984     ,  0.        ,
#           0.        ],
#         [ 0.426     ,  0.32      ,  0.66      ,  0.76      ,  0.        ,
#           0.        ],
#         [ 0.246     ,  0.72533333,  0.328     ,  1.        ,  1.        ,
#           0.        ],
#         [ 0.004     ,  0.73066667,  0.062     ,  0.992     ,  1.        ,
#           0.        ]]),
#  '002518.jpg': array([[ 0.508     ,  0.38554217,  0.724     ,  0.97289157,  0.        ,
#           0.        ],
#         [ 0.168     ,  0.45481928,  0.242     ,  0.6626506 ,  0.        ,
#           0.        ],
#         [ 0.282     ,  0.41566265,  0.45      ,  0.74096386,  0.        ,
#           0.        ],
#         [ 0.294     ,  0.59638554,  0.362     ,  0.89759036,  1.        ,
#           0.        ],
#         [ 0.364     ,  0.60542169,  0.432     ,  0.87951807,  1.        ,
#           0.        ]]),
#  '002545.jpg': array([[ 0.2       ,  0.086     ,  0.54933333,  0.992     ,  0.        ,
#           0.        ],
#         [ 0.48266667,  0.124     ,  0.56266667,  0.264     ,  1.        ,
#           0.        ],
#         [ 0.008     ,  0.054     ,  0.66133333,  0.788     ,  0.        ,
#           0.        ],
#         [ 0.64533333,  0.154     ,  1.        ,  0.56      ,  0.        ,
#           0.        ]]),
#  '002572.jpg': array([[ 0.27      ,  0.29429429,  0.346     ,  0.58558559,  1.        ,
#           0.        ],
#         [ 0.236     ,  0.42642643,  0.272     ,  0.58558559,  1.        ,
#           0.        ],
#         [ 0.74      ,  0.46846847,  1.        ,  0.98198198,  0.        ,
#           0.        ],
#         [ 0.678     ,  0.37537538,  0.858     ,  0.81981982,  0.        ,
#           0.        ],
#         [ 0.738     ,  0.26726727,  0.814     ,  0.48348348,  0.        ,
#           0.        ],
#         [ 0.242     ,  0.09009009,  0.3       ,  0.32132132,  0.        ,
#           0.        ],
#         [ 0.296     ,  0.06606607,  0.364     ,  0.31831832,  0.        ,
#           0.        ],
#         [ 0.402     ,  0.05405405,  0.49      ,  0.25825826,  0.        ,
#           0.        ],
#         [ 0.486     ,  0.06906907,  0.576     ,  0.26126126,  0.        ,
#           0.        ],
#         [ 0.716     ,  0.19219219,  0.792     ,  0.33633634,  0.        ,
#           0.        ],
#         [ 0.564     ,  0.26726727,  0.802     ,  0.86486486,  0.        ,
#           0.        ],
#         [ 0.484     ,  0.25525526,  0.618     ,  0.52552553,  0.        ,
#           0.        ],
#         [ 0.066     ,  0.21921922,  0.42      ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.44      ,  0.24624625,  0.526     ,  0.53153153,  0.        ,
#           0.        ],
#         [ 0.394     ,  0.23123123,  0.478     ,  0.52552553,  0.        ,
#           0.        ]]),
#  '002613.jpg': array([[ 0.554     ,  0.63466667,  0.632     ,  0.92533333,  1.        ,
#           0.        ],
#         [ 0.61      ,  0.60533333,  0.7       ,  1.        ,  1.        ,
#           0.        ],
#         [ 0.694     ,  0.63466667,  0.782     ,  1.        ,  1.        ,
#           0.        ],
#         [ 0.776     ,  0.60266667,  0.844     ,  0.97333333,  1.        ,
#           0.        ],
#         [ 0.84      ,  0.60533333,  0.916     ,  0.95733333,  1.        ,
#           0.        ],
#         [ 0.08      ,  0.05333333,  0.524     ,  0.79466667,  0.        ,
#           0.        ]]),
#  '002641.jpg': array([[ 0.006     ,  0.22666667,  0.402     ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.362     ,  0.288     ,  0.682     ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.55      ,  0.39466667,  1.        ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.528     ,  0.76533333,  0.616     ,  1.        ,  1.        ,
#           0.        ]]),
#  '002658.jpg': array([[ 0.326     ,  0.27627628,  0.378     ,  0.60660661,  1.        ,
#           0.        ],
#         [ 0.206     ,  0.02402402,  0.294     ,  0.34534535,  0.        ,
#           0.        ],
#         [ 0.292     ,  0.03303303,  0.366     ,  0.35435435,  0.        ,
#           0.        ],
#         [ 0.362     ,  0.12912913,  0.468     ,  0.35135135,  0.        ,
#           0.        ],
#         [ 0.548     ,  0.00900901,  0.944     ,  0.97297297,  0.        ,
#           0.        ],
#         [ 0.112     ,  0.54354354,  0.774     ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.558     ,  0.3003003 ,  0.932     ,  0.90690691,  0.        ,
#           0.        ],
#         [ 0.884     ,  0.18018018,  1.        ,  0.88288288,  0.        ,
#           0.        ]]),
#  '002745.jpg': array([[ 0.568     ,  0.118     ,  0.832     ,  0.884     ,  1.        ,
#           0.        ],
#         [ 0.52      ,  0.546     ,  0.97866667,  0.766     ,  0.        ,
#           0.        ],
#         [ 0.808     ,  0.23      ,  1.        ,  0.456     ,  0.        ,
#           0.        ]]),
#  '002881.jpg': array([[ 0.788,  0.682,  0.852,  0.85 ,  1.   ,  0.   ],
#         [ 0.418,  0.818,  0.552,  0.94 ,  0.   ,  0.   ]]),
#  '002931.jpg': array([[ 0.336     ,  0.39733333,  0.368     ,  0.56533333,  1.        ,
#           0.        ],
#         [ 0.576     ,  0.768     ,  0.632     ,  1.        ,  1.        ,
#           0.        ],
#         [ 0.828     ,  0.26666667,  1.        ,  0.55466667,  0.        ,
#           0.        ],
#         [ 0.542     ,  0.21333333,  1.        ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.062     ,  0.34933333,  0.476     ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.744     ,  0.00266667,  0.762     ,  0.07733333,  1.        ,
#           0.        ],
#         [ 0.764     ,  0.00266667,  0.78      ,  0.07733333,  1.        ,
#           0.        ],
#         [ 0.78      ,  0.00266667,  0.796     ,  0.08      ,  1.        ,
#           0.        ],
#         [ 0.794     ,  0.00266667,  0.81      ,  0.07733333,  1.        ,
#           0.        ],
#         [ 0.812     ,  0.00266667,  0.828     ,  0.07733333,  1.        ,
#           0.        ],
#         [ 0.828     ,  0.00266667,  0.846     ,  0.07733333,  1.        ,
#           0.        ],
#         [ 0.844     ,  0.00266667,  0.86      ,  0.07733333,  1.        ,
#           0.        ],
#         [ 0.86      ,  0.00266667,  0.874     ,  0.07733333,  1.        ,
#           0.        ],
#         [ 0.922     ,  0.00266667,  0.942     ,  0.08266667,  1.        ,
#           0.        ],
#         [ 0.906     ,  0.00266667,  0.928     ,  0.08      ,  1.        ,
#           0.        ],
#         [ 0.876     ,  0.00266667,  0.892     ,  0.07733333,  1.        ,
#           0.        ],
#         [ 0.884     ,  0.00266667,  0.908     ,  0.07466667,  1.        ,
#           0.        ],
#         [ 0.002     ,  0.4       ,  0.588     ,  1.        ,  0.        ,
#           0.        ]]),
#  '002939.jpg': array([[ 0.566     ,  0.42933333,  0.632     ,  0.60266667,  1.        ,
#           0.        ],
#         [ 0.318     ,  0.26933333,  0.672     ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.532     ,  0.54933333,  0.738     ,  0.96266667,  0.        ,
#           0.        ],
#         [ 0.076     ,  0.288     ,  0.242     ,  0.62133333,  0.        ,
#           0.        ]]),
#  '002941.jpg': array([[ 0.824     ,  0.14933333,  0.878     ,  0.42133333,  1.        ,
#           0.        ],
#         [ 0.886     ,  0.18933333,  0.986     ,  0.496     ,  1.        ,
#           0.        ],
#         [ 0.766     ,  0.18133333,  0.872     ,  0.49066667,  1.        ,
#           0.        ],
#         [ 0.678     ,  0.15733333,  0.772     ,  0.45333333,  1.        ,
#           0.        ]]),
#  '002953.jpg': array([[ 0.05      ,  0.27567568,  0.186     ,  0.87837838,  1.        ,
#           0.        ],
#         [ 0.188     ,  0.28108108,  0.332     ,  0.91081081,  1.        ,
#           0.        ],
#         [ 0.33      ,  0.27837838,  0.494     ,  0.93783784,  1.        ,
#           0.        ],
#         [ 0.432     ,  0.14054054,  0.832     ,  0.82162162,  0.        ,
#           0.        ],
#         [ 0.178     ,  0.16486486,  0.324     ,  0.38108108,  0.        ,
#           0.        ]]),
#  '002965.jpg': array([[ 0.048     ,  0.46933333,  0.122     ,  0.73066667,  1.        ,
#           0.        ],
#         [ 0.188     ,  0.4       ,  0.256     ,  0.69866667,  1.        ,
#           0.        ],
#         [ 0.264     ,  0.4       ,  0.334     ,  0.65066667,  1.        ,
#           0.        ],
#         [ 0.342     ,  0.408     ,  0.398     ,  0.624     ,  1.        ,
#           0.        ],
#         [ 0.398     ,  0.40266667,  0.462     ,  0.608     ,  1.        ,
#           0.        ],
#         [ 0.47      ,  0.41866667,  0.518     ,  0.64      ,  1.        ,
#           0.        ],
#         [ 0.522     ,  0.408     ,  0.572     ,  0.69333333,  1.        ,
#           0.        ],
#         [ 0.576     ,  0.41333333,  0.632     ,  0.70133333,  1.        ,
#           0.        ],
#         [ 0.632     ,  0.41866667,  0.692     ,  0.70933333,  1.        ,
#           0.        ],
#         [ 0.698     ,  0.42133333,  0.75      ,  0.70933333,  1.        ,
#           0.        ],
#         [ 0.752     ,  0.43466667,  0.82      ,  0.71733333,  1.        ,
#           0.        ],
#         [ 0.418     ,  0.64266667,  0.558     ,  0.99733333,  1.        ,
#           0.        ],
#         [ 0.54      ,  0.69866667,  0.672     ,  1.        ,  1.        ,
#           0.        ],
#         [ 0.024     ,  0.09333333,  0.242     ,  0.512     ,  0.        ,
#           0.        ],
#         [ 0.268     ,  0.05866667,  0.362     ,  0.32      ,  0.        ,
#           0.        ],
#         [ 0.578     ,  0.17066667,  0.748     ,  0.45866667,  0.        ,
#           0.        ],
#         [ 0.346     ,  0.256     ,  0.526     ,  0.53066667,  0.        ,
#           0.        ],
#         [ 0.594     ,  0.304     ,  0.75      ,  0.544     ,  0.        ,
#           0.        ],
#         [ 0.746     ,  0.18133333,  0.854     ,  0.464     ,  0.        ,
#           0.        ],
#         [ 0.664     ,  0.16266667,  0.778     ,  0.42933333,  0.        ,
#           0.        ],
#         [ 0.326     ,  0.11733333,  0.554     ,  0.448     ,  0.        ,
#           0.        ],
#         [ 0.87      ,  0.19733333,  0.986     ,  0.408     ,  0.        ,
#           0.        ],
#         [ 0.83      ,  0.21066667,  0.898     ,  0.37866667,  0.        ,
#           0.        ],
#         [ 0.94      ,  0.224     ,  1.        ,  0.39466667,  0.        ,
#           0.        ],
# ...
#           0.        ]]),
#  '008967.jpg': array([[ 0.458     ,  0.04504505,  0.758     ,  0.99399399,  1.        ,
#           0.        ],
#         [ 0.718     ,  0.04504505,  0.96      ,  0.96696697,  1.        ,
#           0.        ],
#         [ 0.324     ,  0.16216216,  0.52      ,  1.        ,  1.        ,
#           0.        ],
#         [ 0.274     ,  0.21321321,  0.466     ,  0.996997  ,  1.        ,
#           0.        ]]),
#  '008982.jpg': array([[ 0.512     ,  0.192     ,  0.852     ,  0.624     ,  0.        ,
#           0.        ],
#         [ 0.858     ,  0.49333333,  0.976     ,  0.896     ,  1.        ,
#           0.        ]]),
#  '008989.jpg': array([[ 0.288     ,  0.44533333,  0.38      ,  0.58666667,  1.        ,
#           0.        ],
#         [ 0.398     ,  0.48533333,  0.472     ,  0.66666667,  1.        ,
#           0.        ],
#         [ 0.442     ,  0.408     ,  0.554     ,  0.54933333,  1.        ,
#           0.        ],
#         [ 0.514     ,  0.416     ,  0.596     ,  0.53333333,  1.        ,
#           0.        ],
#         [ 0.59      ,  0.50133333,  0.672     ,  0.61866667,  1.        ,
#           0.        ],
#         [ 0.634     ,  0.52533333,  0.716     ,  0.624     ,  1.        ,
#           0.        ],
#         [ 0.684     ,  0.52      ,  0.776     ,  0.61866667,  1.        ,
#           0.        ],
#         [ 0.742     ,  0.504     ,  0.81      ,  0.58933333,  1.        ,
#           0.        ],
#         [ 0.774     ,  0.496     ,  0.84      ,  0.58666667,  1.        ,
#           0.        ]]),
#  '009016.jpg': array([[ 0.49066667,  0.006     ,  0.89066667,  0.904     ,  1.        ,
#           0.        ]]),
#  '009027.jpg': array([[ 0.362     ,  0.20266667,  0.476     ,  0.488     ,  1.        ,
#           0.        ]]),
#  '009100.jpg': array([[ 0.506     ,  0.52892562,  0.798     ,  0.84297521,  1.        ,
#           0.        ]]),
#  '009108.jpg': array([[ 0.53      ,  0.00265957,  0.834     ,  0.93617021,  1.        ,
#           0.        ],
#         [ 0.238     ,  0.00265957,  0.528     ,  0.90957447,  1.        ,
#           0.        ]]),
#  '009174.jpg': array([[ 0.012     ,  0.144     ,  1.        ,  0.856     ,  0.        ,
#           0.        ],
#         [ 0.532     ,  0.672     ,  0.98      ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.08      ,  0.672     ,  0.412     ,  0.87466667,  0.        ,
#           0.        ],
#         [ 0.002     ,  0.74666667,  0.06      ,  0.88266667,  0.        ,
#           0.        ],
#         [ 0.002     ,  0.856     ,  0.918     ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.902     ,  0.256     ,  0.934     ,  0.33066667,  1.        ,
#           0.        ],
#         [ 0.58      ,  0.26666667,  0.608     ,  0.33866667,  1.        ,
#           0.        ],
#         [ 0.278     ,  0.28533333,  0.306     ,  0.34666667,  1.        ,
#           0.        ],
#         [ 0.704     ,  0.25333333,  0.744     ,  0.312     ,  0.        ,
#           0.        ]]),
#  '009242.jpg': array([[ 0.152     ,  0.25866667,  0.97      ,  0.696     ,  0.        ,
#           0.        ],
#         [ 0.532     ,  0.21866667,  0.848     ,  0.57066667,  0.        ,
#           0.        ],
#         [ 0.218     ,  0.248     ,  0.48      ,  0.608     ,  0.        ,
#           0.        ],
#         [ 0.342     ,  0.46133333,  0.384     ,  0.61866667,  1.        ,
#           0.        ],
#         [ 0.102     ,  0.42933333,  0.178     ,  0.65333333,  1.        ,
#           0.        ]]),
#  '009290.jpg': array([[ 0.0925322 ,  0.3343988 ,  0.1772096 ,  0.4458006 ,  0.        ,
#           0.        ],
#         [ 0.69      ,  0.37537538,  0.744     ,  0.60660661,  1.        ,
#           0.        ],
#         [ 0.252     ,  0.18318318,  0.906     ,  0.62462462,  0.        ,
#           0.        ],
#         [ 0.004     ,  0.43243243,  0.116     ,  0.88288288,  0.        ,
#           0.        ]]),
#  '009299.jpg': array([[ 0.176     ,  0.67267267,  1.        ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.802     ,  0.18618619,  1.        ,  0.93993994,  0.        ,
#           0.        ],
#         [ 0.532     ,  0.1951952 ,  0.806     ,  0.84084084,  0.        ,
#           0.        ],
#         [ 0.002     ,  0.14114114,  0.23      ,  0.92492492,  0.        ,
#           0.        ],
#         [ 0.388     ,  0.003003  ,  0.45      ,  0.16516517,  1.        ,
#           0.        ],
#         [ 0.558     ,  0.003003  ,  0.602     ,  0.16816817,  1.        ,
#           0.        ],
#         [ 0.028     ,  0.04504505,  0.056     ,  0.16216216,  1.        ,
#           0.        ]]),
#  '009375.jpg': array([[ 0.27733333,  0.282     ,  0.47466667,  0.476     ,  0.        ,
#           0.        ],
#         [ 0.34133333,  0.292     ,  0.38666667,  0.376     ,  1.        ,
#           0.        ],
#         [ 0.51999707,  0.7126462 ,  0.61406187,  0.7540796 ,  0.        ,
#           0.        ]]),
#  '009388.jpg': array([[ 0.628     ,  0.46133333,  0.772     ,  0.62133333,  0.        ,
#           0.        ],
#         [ 0.518     ,  0.408     ,  0.64      ,  0.584     ,  0.        ,
#           0.        ],
#         [ 0.468     ,  0.70666667,  0.834     ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.2       ,  0.472     ,  0.326     ,  0.672     ,  0.        ,
#           0.        ],
#         [ 0.108     ,  0.608     ,  0.146     ,  0.744     ,  1.        ,
#           0.        ]]),
#  '009420.jpg': array([[ 0.002     ,  0.624     ,  0.808     ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.442     ,  0.056     ,  0.468     ,  0.16533333,  1.        ,
#           0.        ],
#         [ 0.55      ,  0.10133333,  0.59      ,  0.19466667,  1.        ,
#           0.        ],
#         [ 0.304     ,  0.39733333,  0.432     ,  0.68533333,  0.        ,
#           0.        ],
#         [ 0.426     ,  0.59733333,  0.54      ,  0.736     ,  0.        ,
#           0.        ],
#         [ 0.576     ,  0.61866667,  0.738     ,  0.79466667,  0.        ,
#           0.        ],
#         [ 0.14      ,  0.70933333,  0.332     ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.008     ,  0.64533333,  0.13      ,  1.        ,  0.        ,
#           0.        ]]),
#  '009458.jpg': array([[ 0.00422833,  0.04      ,  0.2346723 ,  0.196     ,  1.        ,
#           0.        ],
#         [ 0.23890063,  0.026     ,  0.42706131,  0.22      ,  1.        ,
#           0.        ],
#         [ 0.42706131,  0.048     ,  0.61310782,  0.226     ,  1.        ,
#           0.        ],
#         [ 0.60887949,  0.08      ,  0.76955603,  0.214     ,  1.        ,
#           0.        ],
#         [ 0.71458774,  0.028     ,  0.84989429,  0.132     ,  1.        ,
#           0.        ],
#         [ 0.80338266,  0.104     ,  0.98308668,  0.206     ,  1.        ,
#           0.        ],
#         [ 0.83932347,  0.01      ,  1.        ,  0.13      ,  1.        ,
#           0.        ]]),
#  '009481.jpg': array([[ 0.42      ,  0.81866667,  0.722     ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.794     ,  0.64266667,  1.        ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.016     ,  0.63466667,  0.268     ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.634     ,  0.55733333,  0.776     ,  0.888     ,  0.        ,
#           0.        ],
#         [ 0.526     ,  0.49066667,  0.548     ,  0.6       ,  1.        ,
#           0.        ],
#         [ 0.47      ,  0.52533333,  0.498     ,  0.64      ,  1.        ,
#           0.        ],
#         [ 0.066     ,  0.42666667,  0.38      ,  0.99733333,  0.        ,
#           0.        ],
#         [ 0.614     ,  0.38933333,  0.988     ,  0.94933333,  0.        ,
#           0.        ],
#         [ 0.568     ,  0.35733333,  0.766     ,  0.944     ,  0.        ,
#           0.        ],
#         [ 0.436     ,  0.38133333,  0.596     ,  0.85866667,  0.        ,
#           0.        ],
#         [ 0.232     ,  0.33066667,  0.406     ,  0.90933333,  0.        ,
#           0.        ],
#         [ 0.08      ,  0.272     ,  0.146     ,  0.34666667,  0.        ,
#           0.        ]]),
#  '009497.jpg': array([[ 0.194     ,  0.28266667,  0.598     ,  0.99733333,  0.        ,
#           0.        ],
#         [ 0.356     ,  0.21333333,  0.638     ,  0.68      ,  0.        ,
#           0.        ],
#         [ 0.806     ,  0.84266667,  0.834     ,  0.96266667,  1.        ,
#           0.        ],
#         [ 0.72      ,  0.832     ,  0.754     ,  0.944     ,  1.        ,
#           0.        ]]),
#  '009585.jpg': array([[ 0.002     ,  0.02666667,  0.51      ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.546     ,  0.18933333,  0.924     ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.818     ,  0.04      ,  1.        ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.848     ,  0.66133333,  0.936     ,  0.92533333,  1.        ,
#           0.        ],
#         [ 0.458     ,  0.51733333,  0.506     ,  0.62666667,  1.        ,
#           0.        ],
#         [ 0.398     ,  0.53333333,  0.46      ,  0.66133333,  1.        ,
#           0.        ],
#         [ 0.348     ,  0.53866667,  0.394     ,  0.62933333,  1.        ,
#           0.        ],
#         [ 0.418     ,  0.58133333,  0.498     ,  0.84      ,  1.        ,
#           0.        ],
#         [ 0.488     ,  0.58666667,  0.568     ,  0.848     ,  1.        ,
#           0.        ]]),
#  '009613.jpg': array([[ 0.60533333,  0.492     ,  0.77333333,  0.622     ,  0.        ,
#           0.        ],
#         [ 0.072     ,  0.57      ,  0.38666667,  0.63      ,  0.        ,
#           0.        ],
#         [ 0.288     ,  0.518     ,  0.52      ,  0.636     ,  0.        ,
#           0.        ],
#         [ 0.25066667,  0.532     ,  0.34133333,  0.582     ,  0.        ,
#           0.        ],
#         [ 0.208     ,  0.548     ,  0.376     ,  0.78      ,  0.        ,
#           0.        ],
#         [ 0.00266667,  0.576     ,  0.19466667,  0.814     ,  0.        ,
#           0.        ],
#         [ 0.104     ,  0.482     ,  0.16      ,  0.526     ,  0.        ,
#           0.        ],
#         [ 0.02933333,  0.506     ,  0.30933333,  0.766     ,  0.        ,
#           0.        ],
#         [ 0.45333333,  0.536     ,  0.67466667,  0.67      ,  0.        ,
#           0.        ],
#         [ 0.14133333,  0.526     ,  0.17866667,  0.594     ,  1.        ,
#           0.        ],
#         [ 0.17066667,  0.526     ,  0.2       ,  0.588     ,  1.        ,
#           0.        ],
#         [ 0.19466667,  0.528     ,  0.21866667,  0.596     ,  1.        ,
#           0.        ],
#         [ 0.208     ,  0.518     ,  0.232     ,  0.592     ,  1.        ,
#           0.        ]]),
#  '009647.jpg': array([[ 0.734     ,  0.55466667,  0.778     ,  0.75733333,  1.        ,
#           0.        ],
#         [ 0.796     ,  0.53866667,  0.844     ,  0.74133333,  1.        ,
#           0.        ],
#         [ 0.656     ,  0.50133333,  0.696     ,  0.616     ,  1.        ,
#           0.        ],
#         [ 0.456     ,  0.32533333,  0.498     ,  0.43466667,  1.        ,
#           0.        ],
#         [ 0.3739838 ,  0.63484587,  0.4438764 ,  0.72624373,  0.        ,
#           0.        ],
#         [ 0.4048978 ,  0.55957707,  0.4452204 ,  0.60796427,  0.        ,
#           0.        ],
#         [ 0.7624248 ,  0.48610027,  0.8000592 ,  0.5918352 ,  0.        ,
#           0.        ],
#         [ 0.506     ,  0.02933333,  0.706     ,  0.50133333,  0.        ,
#           0.        ],
#         [ 0.046     ,  0.61066667,  0.448     ,  0.99733333,  0.        ,
#           0.        ]]),
#  '009654.jpg': array([[ 0.003003  ,  0.166     ,  0.88888889,  1.        ,  0.        ,
#           0.        ],
#         [ 0.66066066,  0.75      ,  0.82582583,  0.944     ,  1.        ,
#           0.        ]]),
#  '009664.jpg': array([[ 0.296     ,  0.002     ,  0.85333333,  1.        ,  1.        ,
#           0.        ]]),
#  '009666.jpg': array([[ 0.488     ,  0.308     ,  0.81866667,  1.        ,  1.        ,
#           0.        ],
#         [ 0.00266667,  0.002     ,  0.816     ,  1.        ,  0.        ,
#           0.        ]]),
#  '009679.jpg': array([[ 0.265625  ,  0.03333333,  0.4875    ,  0.42083333,  1.        ,
#           0.        ],
#         [ 0.50625   ,  0.0625    ,  0.63125   ,  0.44583333,  1.        ,
#           0.        ],
#         [ 0.63125   ,  0.19166667,  0.7125    ,  0.42083333,  1.        ,
#           0.        ],
#         [ 0.7375    ,  0.0625    ,  0.890625  ,  0.41666667,  1.        ,
#           0.        ],
#         [ 0.88125   ,  0.125     ,  0.909375  ,  0.44583333,  1.        ,
#           0.        ]]),
#  '009687.jpg': array([[ 0.524     ,  0.16      ,  1.        ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.002     ,  0.2       ,  0.556     ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.81      ,  0.44      ,  1.        ,  0.728     ,  1.        ,
#           0.        ],
#         [ 0.056     ,  0.69333333,  0.192     ,  1.        ,  1.        ,
#           0.        ]]),
#  '009709.jpg': array([[ 0.68533333,  0.002     ,  1.        ,  0.996     ,  1.        ,
#           0.        ],
#         [ 0.352     ,  0.004     ,  0.72266667,  0.99      ,  1.        ,
#           0.        ],
#         [ 0.00266667,  0.002     ,  0.376     ,  0.978     ,  1.        ,
#           0.        ]]),
#  '009726.jpg': array([[ 0.464     ,  0.22933333,  0.892     ,  0.84      ,  0.        ,
#           0.        ],
#         [ 0.12      ,  0.19466667,  0.594     ,  0.89333333,  0.        ,
#           0.        ],
#         [ 0.002     ,  0.56      ,  0.158     ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.586     ,  0.72      ,  0.66      ,  0.99733333,  1.        ,
#           0.        ],
#         [ 0.718     ,  0.70133333,  0.784     ,  0.98666667,  1.        ,
#           0.        ],
#         [ 0.126     ,  0.792     ,  0.978     ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.002     ,  0.41866667,  0.232     ,  0.64533333,  0.        ,
#           0.        ],
#         [ 0.002     ,  0.576     ,  0.168     ,  1.        ,  0.        ,
#           0.        ]]),
#  '009878.jpg': array([[ 0.148     ,  0.31733333,  0.748     ,  0.93066667,  0.        ,
#           0.        ],
#         [ 0.026     ,  0.87466667,  0.098     ,  1.        ,  1.        ,
#           0.        ],
#         [ 0.174     ,  0.28266667,  0.442     ,  0.67733333,  0.        ,
#           0.        ],
#         [ 0.704     ,  0.29066667,  0.886     ,  0.856     ,  0.        ,
#           0.        ],
#         [ 0.494     ,  0.27733333,  0.71      ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.34      ,  0.29333333,  0.56      ,  0.936     ,  0.        ,
#           0.        ],
#         [ 0.034     ,  0.008     ,  0.326     ,  0.56      ,  0.        ,
#           0.        ]]),
#  '009902.jpg': array([[ 0.242     ,  0.152     ,  0.3       ,  0.34133333,  1.        ,
#           0.        ],
#         [ 0.21      ,  0.18133333,  0.258     ,  0.368     ,  1.        ,
#           0.        ],
#         [ 0.27      ,  0.13866667,  0.31      ,  0.304     ,  1.        ,
#           0.        ],
#         [ 0.6435414 ,  0.53669253,  0.6932652 ,  0.58089147,  0.        ,
#           0.        ],
#         [ 0.299895  ,  0.86818427,  0.4291768 ,  0.96836827,  0.        ,
#           0.        ],
#         [ 0.699895  ,  0.713488  ,  0.7672984 ,  0.79599253,  0.        ,
#           0.        ]]),
#  '009917.jpg': array([[ 0.022     ,  0.656     ,  1.        ,  1.        ,  0.        ,
#           0.        ],
#         [ 0.504     ,  0.328     ,  0.796     ,  0.58133333,  0.        ,
#           0.        ],
#         [ 0.026     ,  0.33066667,  0.386     ,  0.69333333,  0.        ,
#           0.        ],
#         [ 0.004     ,  0.06666667,  0.412     ,  0.67466667,  0.        ,
#           0.        ],
#         [ 0.604     ,  0.136     ,  0.904     ,  0.65066667,  0.        ,
#           0.        ],
#         [ 0.9       ,  0.25333333,  1.        ,  0.89866667,  1.        ,
#           0.        ]])}

# %%
class Generator(object):
    def __init__(self, gt, bbox_util,
                 batch_size, path_prefix,
                 train_keys, val_keys, image_size,
                 saturation_var=0.5,
                 brightness_var=0.5,
                 contrast_var=0.5,
                 lighting_std=0.5,
                 hflip_prob=0.5,
                 vflip_prob=0.5,
                 do_crop=True,
                 crop_area_range=[0.75, 1.0],
                 aspect_ratio_range=[3./4., 4./3.]):
        self.gt = gt
        self.bbox_util = bbox_util
        self.batch_size = batch_size
        self.path_prefix = path_prefix
        self.train_keys = train_keys
        self.val_keys = val_keys
        self.train_batches = len(train_keys)
        self.val_batches = len(val_keys)
        self.image_size = image_size
        self.color_jitter = []
        if saturation_var:
            self.saturation_var = saturation_var
            self.color_jitter.append(self.saturation)
        if brightness_var:
            self.brightness_var = brightness_var
            self.color_jitter.append(self.brightness)
        if contrast_var:
            self.contrast_var = contrast_var
            self.color_jitter.append(self.contrast)
        self.lighting_std = lighting_std
        self.hflip_prob = hflip_prob
        self.vflip_prob = vflip_prob
        self.do_crop = do_crop
        self.crop_area_range = crop_area_range
        self.aspect_ratio_range = aspect_ratio_range
        
    def grayscale(self, rgb):
        return rgb.dot([0.299, 0.587, 0.114])

    def saturation(self, rgb):
        gs = self.grayscale(rgb)
        alpha = 2 * np.random.random() * self.saturation_var 
        alpha += 1 - self.saturation_var
        rgb = rgb * alpha + (1 - alpha) * gs[:, :, None]
        return np.clip(rgb, 0, 255)

    def brightness(self, rgb):
        alpha = 2 * np.random.random() * self.brightness_var 
        alpha += 1 - self.saturation_var
        rgb = rgb * alpha
        return np.clip(rgb, 0, 255)

    def contrast(self, rgb):
        gs = self.grayscale(rgb).mean() * np.ones_like(rgb)
        alpha = 2 * np.random.random() * self.contrast_var 
        alpha += 1 - self.contrast_var
        rgb = rgb * alpha + (1 - alpha) * gs
        return np.clip(rgb, 0, 255)

    def lighting(self, img):
        cov = np.cov(img.reshape(-1, 3) / 255.0, rowvar=False)
        eigval, eigvec = np.linalg.eigh(cov)
        noise = np.random.randn(3) * self.lighting_std
        noise = eigvec.dot(eigval * noise) * 255
        img += noise
        return np.clip(img, 0, 255)
    
    def horizontal_flip(self, img, y):
        if np.random.random() < self.hflip_prob:
            img = img[:, ::-1]
            y[:, [0, 2]] = 1 - y[:, [2, 0]]
        return img, y
    
    def vertical_flip(self, img, y):
        if np.random.random() < self.vflip_prob:
            img = img[::-1]
            y[:, [1, 3]] = 1 - y[:, [3, 1]]
        return img, y
    
    def random_sized_crop(self, img, targets):
        img_w = img.shape[1]
        img_h = img.shape[0]
        img_area = img_w * img_h
        random_scale = np.random.random()
        random_scale *= (self.crop_area_range[1] -
                         self.crop_area_range[0])
        random_scale += self.crop_area_range[0]
        target_area = random_scale * img_area
        random_ratio = np.random.random()
        random_ratio *= (self.aspect_ratio_range[1] -
                         self.aspect_ratio_range[0])
        random_ratio += self.aspect_ratio_range[0]
        w = np.round(np.sqrt(target_area * random_ratio))     
        h = np.round(np.sqrt(target_area / random_ratio))
        if np.random.random() < 0.5:
            w, h = h, w
        w = min(w, img_w)
        w_rel = w / img_w
        w = int(w)
        h = min(h, img_h)
        h_rel = h / img_h
        h = int(h)
        x = np.random.random() * (img_w - w)
        x_rel = x / img_w
        x = int(x)
        y = np.random.random() * (img_h - h)
        y_rel = y / img_h
        y = int(y)
        img = img[y:y+h, x:x+w]
        new_targets = []
        for box in targets:
            cx = 0.5 * (box[0] + box[2])
            cy = 0.5 * (box[1] + box[3])
            if (x_rel < cx < x_rel + w_rel and
                y_rel < cy < y_rel + h_rel):
                xmin = (box[0] - x_rel) / w_rel
                ymin = (box[1] - y_rel) / h_rel
                xmax = (box[2] - x_rel) / w_rel
                ymax = (box[3] - y_rel) / h_rel
                xmin = max(0, xmin)
                ymin = max(0, ymin)
                xmax = min(1, xmax)
                ymax = min(1, ymax)
                box[:4] = [xmin, ymin, xmax, ymax]
                new_targets.append(box)
        new_targets = np.asarray(new_targets).reshape(-1, targets.shape[1])
        return img, new_targets
    
    def generate(self, train=True):
        while True:
            if train:
                shuffle(self.train_keys)
                keys = self.train_keys
            else:
                shuffle(self.val_keys)
                keys = self.val_keys
            inputs = []
            targets = []
            for key in keys:            
                if key.split('.')[-1] != 'jpg':
                    key += '.jpg'
                img_path = self.path_prefix + key
                img = imread(img_path).astype('float32')
                y = self.gt[key].copy()
                if train and self.do_crop:
                    img, y = self.random_sized_crop(img, y)
                img = imresize(img, self.image_size).astype('float32')
                if train:
                    shuffle(self.color_jitter)
                    for jitter in self.color_jitter:
                        img = jitter(img)
                    if self.lighting_std:
                        img = self.lighting(img)
                    if self.hflip_prob > 0:
                        img, y = self.horizontal_flip(img, y)
                    if self.vflip_prob > 0:
                        img, y = self.vertical_flip(img, y)
                y = self.bbox_util.assign_boxes(y)
                inputs.append(img)                
                targets.append(y)
                if len(targets) == self.batch_size:
                    tmp_inp = np.array(inputs)
                    tmp_targets = np.array(targets)
                    inputs = []
                    targets = []
                    yield preprocess_input(tmp_inp), tmp_targets

# %%
path_prefix = 'VOCdevkit/VOC2007/JPEGImages/'
gen = Generator(gt, bbox_util, 9, path_prefix,
                train_keys, val_keys,
                (input_shape[0], input_shape[1]), do_crop=False)

# %%
model = SSD300(input_shape, num_classes=NUM_CLASSES)
model.load_weights('weights_SSD300.hdf5', by_name=True)

# %%
freeze = ['input_1', 'conv1_1', 'conv1_2', 'pool1',
          'conv2_1', 'conv2_2', 'pool2',
          'conv3_1', 'conv3_2', 'conv3_3', 'pool3']#,
#           'conv4_1', 'conv4_2', 'conv4_3', 'pool4']

for L in model.layers:
    if L.name in freeze:
        L.trainable = False

# %%
def schedule(epoch, decay=0.9):
    return base_lr * decay**(epoch)

callbacks = [keras.callbacks.ModelCheckpoint('./checkpoints/weights.{epoch:02d}-{val_loss:.2f}.hdf5',
                                             verbose=1,
                                             save_weights_only=True),
             keras.callbacks.LearningRateScheduler(schedule)]

# %%
base_lr = 3e-4
optim = keras.optimizers.Adam(lr=base_lr)
# optim = keras.optimizers.RMSprop(lr=base_lr)
# optim = keras.optimizers.SGD(lr=base_lr, momentum=0.9, decay=decay, nesterov=True)
model.compile(optimizer=optim,
              loss=MultiboxLoss(NUM_CLASSES, neg_pos_ratio=2.0).compute_loss)

# %%
nb_epoch = 30
history = model.fit_generator(gen.generate(True), gen.train_batches,
                              nb_epoch, verbose=1,
                              callbacks=callbacks,
                              validation_data=gen.generate(False),
                              nb_val_samples=gen.val_batches,
                              nb_worker=1)
# Out:
# /home/nakamura/.pyenv/versions/anaconda3-4.0.0/envs/dynamic_fs/lib/python3.5/site-packages/tensorflow/python/ops/gradients_impl.py:91: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Epoch 1/30
# 288/296 [============================>.] - ETA: 0s - loss: 3.1257
# /home/nakamura/.pyenv/versions/anaconda3-4.0.0/envs/dynamic_fs/lib/python3.5/site-packages/keras/engine/training.py:1573: UserWarning: Epoch comprised more than `samples_per_epoch` samples, which might affect learning results. Set `samples_per_epoch` correctly to avoid this warning.
#   warnings.warn('Epoch comprised more than '
# Epoch 00000: saving model to ./checkpoints/weights.00-2.75.hdf5
# 297/296 [==============================] - 25s - loss: 3.1064 - val_loss: 2.7452
# Epoch 2/30
# 288/296 [============================>.] - ETA: 0s - loss: 2.6190Epoch 00001: saving model to ./checkpoints/weights.01-2.71.hdf5
# 297/296 [==============================] - 22s - loss: 2.6126 - val_loss: 2.7137
# Epoch 3/30
# 288/296 [============================>.] - ETA: 0s - loss: 2.3592Epoch 00002: saving model to ./checkpoints/weights.02-2.61.hdf5
# 297/296 [==============================] - 22s - loss: 2.3600 - val_loss: 2.6094
# Epoch 4/30
# 288/296 [============================>.] - ETA: 0s - loss: 2.1231Epoch 00003: saving model to ./checkpoints/weights.03-2.48.hdf5
# 297/296 [==============================] - 22s - loss: 2.1204 - val_loss: 2.4814
# Epoch 5/30
# 288/296 [============================>.] - ETA: 0s - loss: 1.8303Epoch 00004: saving model to ./checkpoints/weights.04-2.48.hdf5
# 297/296 [==============================] - 22s - loss: 1.8258 - val_loss: 2.4819
# Epoch 6/30
# 288/296 [============================>.] - ETA: 0s - loss: 1.7399Epoch 00005: saving model to ./checkpoints/weights.05-2.38.hdf5
# 297/296 [==============================] - 25s - loss: 1.7408 - val_loss: 2.3758
# Epoch 7/30
# 288/296 [============================>.] - ETA: 0s - loss: 1.5743Epoch 00006: saving model to ./checkpoints/weights.06-2.21.hdf5
# 297/296 [==============================] - 22s - loss: 1.5736 - val_loss: 2.2072
# Epoch 8/30
# 288/296 [============================>.] - ETA: 0s - loss: 1.4439Epoch 00007: saving model to ./checkpoints/weights.07-2.32.hdf5
# 297/296 [==============================] - 22s - loss: 1.4442 - val_loss: 2.3180
# Epoch 9/30
# 288/296 [============================>.] - ETA: 0s - loss: 1.3645Epoch 00008: saving model to ./checkpoints/weights.08-2.24.hdf5
# 297/296 [==============================] - 22s - loss: 1.3717 - val_loss: 2.2418
# Epoch 10/30
# 288/296 [============================>.] - ETA: 0s - loss: 1.2266Epoch 00009: saving model to ./checkpoints/weights.09-2.34.hdf5
# 297/296 [==============================] - 22s - loss: 1.2234 - val_loss: 2.3372
# Epoch 11/30
# 288/296 [============================>.] - ETA: 0s - loss: 1.1914Epoch 00010: saving model to ./checkpoints/weights.10-2.23.hdf5
# 297/296 [==============================] - 22s - loss: 1.1960 - val_loss: 2.2293
# Epoch 12/30
# 288/296 [============================>.] - ETA: 0s - loss: 1.0546Epoch 00011: saving model to ./checkpoints/weights.11-2.20.hdf5
# 297/296 [==============================] - 23s - loss: 1.0571 - val_loss: 2.2011
# Epoch 13/30
# 288/296 [============================>.] - ETA: 0s - loss: 0.9684Epoch 00012: saving model to ./checkpoints/weights.12-2.21.hdf5
# 297/296 [==============================] - 22s - loss: 0.9764 - val_loss: 2.2050
# Epoch 14/30
# 288/296 [============================>.] - ETA: 0s - loss: 0.9701Epoch 00013: saving model to ./checkpoints/weights.13-2.46.hdf5
# 297/296 [==============================] - 23s - loss: 0.9595 - val_loss: 2.4602
# Epoch 15/30
# 288/296 [============================>.] - ETA: 0s - loss: 0.8276Epoch 00014: saving model to ./checkpoints/weights.14-2.13.hdf5
# 297/296 [==============================] - 23s - loss: 0.8239 - val_loss: 2.1343
# Epoch 16/30
# 288/296 [============================>.] - ETA: 0s - loss: 0.8475Epoch 00015: saving model to ./checkpoints/weights.15-2.10.hdf5
# 297/296 [==============================] - 24s - loss: 0.8381 - val_loss: 2.0953
# Epoch 17/30
# 288/296 [============================>.] - ETA: 0s - loss: 0.7528Epoch 00016: saving model to ./checkpoints/weights.16-2.27.hdf5
# 297/296 [==============================] - 23s - loss: 0.7555 - val_loss: 2.2672
# Epoch 18/30
# 288/296 [============================>.] - ETA: 0s - loss: 0.7401Epoch 00017: saving model to ./checkpoints/weights.17-2.46.hdf5
# 297/296 [==============================] - 22s - loss: 0.7390 - val_loss: 2.4572
# Epoch 19/30
# 288/296 [============================>.] - ETA: 0s - loss: 0.7303Epoch 00018: saving model to ./checkpoints/weights.18-2.20.hdf5
# 297/296 [==============================] - 22s - loss: 0.7284 - val_loss: 2.1986
# Epoch 20/30
# 288/296 [============================>.] - ETA: 0s - loss: 0.6538Epoch 00019: saving model to ./checkpoints/weights.19-2.17.hdf5
# 297/296 [==============================] - 22s - loss: 0.6511 - val_loss: 2.1666
# Epoch 21/30
# 288/296 [============================>.] - ETA: 0s - loss: 0.6116Epoch 00020: saving model to ./checkpoints/weights.20-2.09.hdf5
# 297/296 [==============================] - 23s - loss: 0.6088 - val_loss: 2.0917
# Epoch 22/30
# 288/296 [============================>.] - ETA: 0s - loss: 0.6438Epoch 00021: saving model to ./checkpoints/weights.21-2.42.hdf5
# 297/296 [==============================] - 21s - loss: 0.6418 - val_loss: 2.4176
# Epoch 23/30
# 288/296 [============================>.] - ETA: 0s - loss: 0.5763Epoch 00022: saving model to ./checkpoints/weights.22-2.30.hdf5
# 297/296 [==============================] - 23s - loss: 0.5737 - val_loss: 2.2953
# Epoch 24/30
# 288/296 [============================>.] - ETA: 0s - loss: 0.5683Epoch 00023: saving model to ./checkpoints/weights.23-2.03.hdf5
# 297/296 [==============================] - 22s - loss: 0.5716 - val_loss: 2.0312
# Epoch 25/30
# 288/296 [============================>.] - ETA: 0s - loss: 0.5964Epoch 00024: saving model to ./checkpoints/weights.24-2.41.hdf5
# 297/296 [==============================] - 22s - loss: 0.5975 - val_loss: 2.4107
# Epoch 26/30
# 288/296 [============================>.] - ETA: 0s - loss: 0.5440Epoch 00025: saving model to ./checkpoints/weights.25-2.16.hdf5
# 297/296 [==============================] - 22s - loss: 0.5422 - val_loss: 2.1585
# Epoch 27/30
# 288/296 [============================>.] - ETA: 0s - loss: 0.5204Epoch 00026: saving model to ./checkpoints/weights.26-1.83.hdf5
# 297/296 [==============================] - 23s - loss: 0.5221 - val_loss: 1.8331
# Epoch 28/30
# 288/296 [============================>.] - ETA: 0s - loss: 0.5233Epoch 00027: saving model to ./checkpoints/weights.27-2.16.hdf5
# 297/296 [==============================] - 22s - loss: 0.5163 - val_loss: 2.1629
# Epoch 29/30
# 288/296 [============================>.] - ETA: 0s - loss: 0.5062Epoch 00028: saving model to ./checkpoints/weights.28-2.35.hdf5
# 297/296 [==============================] - 23s - loss: 0.4993 - val_loss: 2.3463
# Epoch 30/30
# 288/296 [============================>.] - ETA: 0s - loss: 0.5109Epoch 00029: saving model to ./checkpoints/weights.29-2.48.hdf5
# 297/296 [==============================] - 22s - loss: 0.5116 - val_loss: 2.4764

# %%
inputs = []
images = []
# img_path = path_prefix + sorted(val_keys)[-1]
img_path = path_prefix + sorted(train_keys)[8]
img_path = path_prefix + "0000021.jpg"
img = image.load_img(img_path, target_size=(300, 300))
img = image.img_to_array(img)
images.append(imread(img_path))
inputs.append(img.copy())
inputs = preprocess_input(np.array(inputs))

# %%
preds = model.predict(inputs, batch_size=1, verbose=1)
results = bbox_util.detection_out(preds)
# Out:
# 1/1 [==============================] - 1s

# %%
for i, img in enumerate(images):
    # Parse the outputs.
    det_label = results[i][:, 0]
    det_conf = results[i][:, 1]
    det_xmin = results[i][:, 2]
    det_ymin = results[i][:, 3]
    det_xmax = results[i][:, 4]
    det_ymax = results[i][:, 5]

    # Get detections with confidence higher than 0.6.
    top_indices = [i for i, conf in enumerate(det_conf) if conf >= 0.6]
#     top_indices = [i for i, label in enumerate(det_label) if label == 2]

    top_conf = det_conf[top_indices]
    top_label_indices = det_label[top_indices].tolist()
    top_xmin = det_xmin[top_indices]
    top_ymin = det_ymin[top_indices]
    top_xmax = det_xmax[top_indices]
    top_ymax = det_ymax[top_indices]

    colors = plt.cm.hsv(np.linspace(0, 1, 3)).tolist()

    plt.imshow(img / 255.)
    currentAxis = plt.gca()

    for i in range(top_conf.shape[0]):
        xmin = int(round(top_xmin[i] * img.shape[1]))
        ymin = int(round(top_ymin[i] * img.shape[0]))
        xmax = int(round(top_xmax[i] * img.shape[1]))
        ymax = int(round(top_ymax[i] * img.shape[0]))
        score = top_conf[i]
        label = int(top_label_indices[i])
#         label_name = voc_classes[label - 1]
        display_txt = '{:0.2f}, {}'.format(score, label)
        coords = (xmin, ymin), xmax-xmin+1, ymax-ymin+1
        color = colors[label]
        currentAxis.add_patch(plt.Rectangle(*coords, fill=False, edgecolor=color, linewidth=2))
        currentAxis.text(xmin, ymin, display_txt, bbox={'facecolor':color, 'alpha':0.5})
    
    plt.show()

# %%
def show_result(img, rectangles):
